# %%
import json 
import pandas as pd
import numpy as np
from pathlib import Path
import PIL
from PIL import Image
import cv2 
import torch
import tqdm
import os
import cv2
import matplotlib.pyplot as plt

# %%
import random
import glob

root_pth = '/media/SSD/rheology_ForFLAVR/Glycerol-water-mixtures-demo/GLY10P100/2/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736/'
ims = sorted(glob.glob(f"{root_pth}*.png")) 
ims = random.choices(ims, k=5)
for im in ims:
    #print(im)
    name_im = im.split('/')[-1]
    #print(name_im)
    image = cv2.imread(im)
    sZ = os.path.getsize(im)
    print(f"Images Name : **{name_im}, --> Shape ", image.shape)
    print(f"image size: {sZ:,} bytes")
    plt.axis("off")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000757_inter0000000758.png, --> Shape  (800, 800, 3)
# image size: 569,249 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000330_inter0000000331.png, --> Shape  (800, 800, 3)
# image size: 568,498 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000729_inter0000000730.png, --> Shape  (800, 800, 3)
# image size: 571,261 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001916_inter0000001917.png, --> Shape  (800, 800, 3)
# image size: 570,377 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001899_inter0000001900.png, --> Shape  (800, 800, 3)
# image size: 571,669 bytes

# %%
print(len(ims))
ims
# Out:
# 1998
# ['/media/SSD/rheology_ForFLAVR/Glycerol-water-mixtures-demo/GLY10P100/2/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000002_inter0000000003.png',
#  '/media/SSD/rheology_ForFLAVR/Glycerol-water-mixtures-demo/GLY10P100/2/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000003_inter0000000004.png',
#  '/media/SSD/rheology_ForFLAVR/Glycerol-water-mixtures-demo/GLY10P100/2/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000004_inter0000000005.png',
#  '/media/SSD/rheology_ForFLAVR/Glycerol-water-mixtures-demo/GLY10P100/2/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000000005_inter0000000006.png',
# ...

# %% [markdown]
# ## SCP
#
# - Frame Interpolation Vs. Original

# %%
import random
import glob


listframe = ['GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001998.jpg',
                'GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001999.jpg',
                'GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001999_inter0000002000.png',
                'GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000002000.jpg',
                'GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000002001.jpg']
root_pth = '/media/SSD/rheology_ForFLAVR/Glycerol-water-mixtures-demo/GLY10P100/2/GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_sequence_FLAVR/'
for frame in listframe:
    im = f'{root_pth}{frame}'
    name_im = im.split('/')[-1]
    #print(name_im)
    image = cv2.imread(im)
    sZ = os.path.getsize(im)
    print(f"Images Name : **{name_im}, --> Shape ", image.shape)
    print(f"image size: {sZ:,} bytes")
    plt.axis("off")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001998.jpg, --> Shape  (800, 800, 3)
# image size: 111,493 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001999.jpg, --> Shape  (800, 800, 3)
# image size: 111,566 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000001999_inter0000002000.png, --> Shape  (800, 800, 3)
# image size: 569,392 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000002000.jpg, --> Shape  (800, 800, 3)
# image size: 111,547 bytes
# Images Name : **GLY10P100_D0_30HZ_20XINF_UWELL_20220721_124736_0000002001.jpg, --> Shape  (800, 800, 3)
# image size: 111,563 bytes
